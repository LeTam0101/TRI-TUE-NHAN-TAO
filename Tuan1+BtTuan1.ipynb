# %% [markdown]
# <a href="https://colab.research.google.com/github/LeTam0101/TRI-TUE-NHAN-TAO/blob/main/Tuan1%2BBtTuan1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
value1=input('Nhap vao so thu 1:')
# Out:
# Nhap vao so thu 1:6

# %%
value2=input('Nhap vao so thu 2:')
# Out:
# Nhap vao so thu 2:4

# %%
value1+value2
# Out:
# '64'

# %%
int(value1+value2)
# Out:
# 64

# %%
int(value1)+int(value2)
# Out:
# 10

# %%
with open('text.txt', mode='w') as accounnts:         # w la write
  accounnts.write('201462 Le Van A 8.0 \n')
  accounnts.write('201462 Nguyen Van B 9.0 \n')
  accounnts.write('201462 Le Nguyen Van 8.5 \n')
  accounnts.write('201461 Vy Nguyen Van 7.5 \n')
  accounnts.write('201461 Dinh La Thang 8.5 \n')
  accounnts.write('201462 Trinh Van Quyet 6.5 \n')
  accounnts.write('201462 La Van Quyet 8.0 \n')
  accounnts.write('201462 Le Tung Anh 8.0 \n')
  accounnts.write('201461 Trinh Thuy Ngan 9.0 \n')
  accounnts.write('201462 Nguyen Thi Kim Ngan 9.5 \n')
  accounnts.write('201462 Cao la Vy 6.5 \n')

# %%
with open('text1', mode='w') as accounnts:          # w là write
  print('201461 Le Van A 8.0', file= accounnts)     # accounnts.write('201462 Le Van A 8.0 \n')
  print('201461 Le Van C 9.0', file= accounnts)     # ==print('201461 Le Van A 8.0', file= accounnts)

# %%
with open ('file_ten.csv', mode="r") as accounts:
  print ({'khoa':<20}{'score':>20})
  for record in accounts:
    name, score = record.split()
    print(f'{name:<20}{score:>20}')
# Out:
#   File "<ipython-input-7-5a8d9ef1ed4c>", line 2
#     print ({'khoa':<20}{'score':>20})
#                    ^
# SyntaxError: invalid syntax

# %%
with open('file_ten.csv',mode='r' )as accoount:
  print(f'.{"MSSV":<10}{"Name":<20}{"Scove":>4}')
  for record in accoount:
    MSSV, Name, score= record.split()
    print(f'.{"MSSV":<10}{"Name":<20}{"Scove":>4}')
# Out:
# .MSSV      Name                Scove
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-29-f36dfb24e384> in <module>
#       1 with open('file_ten.csv',mode='r' )as accoount:
#       2   print(f'.{"MSSV":<10}{"Name":<20}{"Scove":>4}')
# ----> 3   for record in accoount:
#       4     MSSV, Name, score= record.split()
#       5     print(f'.{"MSSV":<10}{"Name":<20}{"Scove":>4}')
#
# /usr/lib/python3.8/codecs.py in decode(self, input, final)
#     320         # decode input (taking the buffer into account)
#     321         data = self.buffer + input
# --> 322         (result, consumed) = self._buffer_decode(data, self.errors, final)
#     323         # keep undecoded input until the next call
#     324         self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe1 in position 18: invalid continuation byte

# %%
import pandas as pd        
url = 'file_ten.csv'
dataframe = pd.read_csv(url)
dataframe.head(4)                #lay du lieu den hang 4
# Out:
#        MSSV      Ho Va Ten  Nam nhap hoc                 Khoa  Diem
# 0  20146526       Le Van A            20                  CKM   8.0
# 1  20146565   Nguyen Van B            20                  CKM   9.0
# 2  19146262  Dinh La Thang            19  Cong nghe thuc pham   8.5
# 3  21996543      Cao Vi Mo            21          Hoa loc dau   7.5

# %%
import pandas as pd        
url = 'file_ten.csv'
dataframe = pd.read_csv(url)
dataframe.iloc[10]            #lay du lieu hang so 10
# Out:
# MSSV              24876578
# Ho Va Ten       Dang A Phu
# Nam nhap hoc            24
# Khoa               Kinh te
# Diem                   9.5
# Name: 10, dtype: object

# %%
import pandas as pd        
url = 'file_ten.csv'
dataframe = pd.read_csv(url)
dataframe.iloc[0:3]
# Out:
#        MSSV      Ho Va Ten  Nam nhap hoc                 Khoa  Diem
# 0  20146526       Le Van A            20                  CKM   8.0
# 1  20146565   Nguyen Van B            20                  CKM   9.0
# 2  19146262  Dinh La Thang            19  Cong nghe thuc pham   8.5

# %%
import pandas as pd        
url = 'file_ten.csv'
dataframe = pd.read_csv(url)
dataframe.iloc[7:]
# Out:
#         MSSV           Ho Va Ten  Nam nhap hoc                   Khoa  Diem
# 7   18161515        Co Sinh Vien            18    Cong nghe thuc pham   9.0
# 8   22988989           Le Ngo AI            22                    CKM   8.5
# 9   23567865         Sieu Cao Co            23                    FME   8.5
# 10  24876578          Dang A Phu            24                Kinh te   9.5
# 11  21287628     Huynh My Phuong            21  Ke hoach hoa gia dinh  10.0
# 12  23237627        Nguyen Van C            23                   Luat   8.0
# 13  24542726  Nguyen Thi Mong Mo            24          Tuong lai hoc   9.0

# %%
import pandas as pd                   # tao hang va cot
dataframe = pd.DataFrame()
dataframe ['Ho Va Ten'] = ['Sieu Tri Tue','Le Ngo AI']
dataframe ['Student ID'] = [21986541,22988989]
dataframe ['Score']=[7,10]
dataframe
# Out:
#       Ho Va Ten  Student ID  Score
# 0  Sieu Tri Tue    21986541      7
# 1     Le Ngo AI    22988989     10

# %%
import pandas as pd            #Lay thong tin cua 1 nguoi, hoac nhieu nguoi co cung ten
url = 'file_ten.csv'           #hoac nhieu nguoi co cung ten
dataframe = pd.read_csv(url)
#dataframe.head(10)
dataframe = dataframe.set_index(dataframe['Ho Va Ten'])
dataframe.loc['Nguyen Thi Mong Mo']
# Out:
#                         MSSV           Ho Va Ten  Nam nhap hoc  \
# Ho Va Ten
# Nguyen Thi Mong Mo  24542726  Nguyen Thi Mong Mo            24
# Nguyen Thi Mong Mo  29290292  Nguyen Thi Mong Mo            26
#
#                                Khoa  Diem
# Ho Va Ten
# Nguyen Thi Mong Mo    Tuong lai hoc   9.0
# Nguyen Thi Mong Mo  Tinh truong hoc   9.5

# %%
import pandas as pd
url = 'file_ten.csv'
dataframe = pd.read_csv(url)
dataframe[dataframe['Ho Va Ten']=='Nguyen Thi Mong Mo'].head(5)
# Out:
#         MSSV           Ho Va Ten  Nam nhap hoc             Khoa  Diem
# 13  24542726  Nguyen Thi Mong Mo            24    Tuong lai hoc   9.0
# 14  29290292  Nguyen Thi Mong Mo            26  Tinh truong hoc   9.5

# %%
import pandas as pd
url = 'file_ten.csv'
dataframe = pd.read_csv(url)
dataframe[dataframe['Khoa']=='CKM'].head(5)      # So 5 la tim toi da 5 nguoi
# Out:
#        MSSV     Ho Va Ten  Nam nhap hoc Khoa  Diem
# 0  20146526      Le Van A            20  CKM   8.0
# 1  20146565  Nguyen Van B            20  CKM   9.0
# 8  22988989     Le Ngo AI            22  CKM   8.5

# %%
import pandas as pd
url = 'file_ten.csv'
dataframe = pd.read_csv(url)
dataframe[(dataframe['Khoa']=='CKM') & (dataframe['Nam nhap hoc']==20) & (dataframe['Diem']>= 5)].head(7)
# Out:
#        MSSV     Ho Va Ten  Nam nhap hoc Khoa  Diem
# 0  20146526      Le Van A            20  CKM   8.0
# 1  20146565  Nguyen Van B            20  CKM   9.0

# %%
import pandas as pd            # lay thong tin cua cot
url = 'file_ten.csv'
dataframe = pd.read_csv(url)
dataframe['Khoa'].unique()
# Out:
# array(['CKM', 'Cong nghe thuc pham', 'Hoa loc dau', 'Cong Nghe In',
#        'Ke hoach hoa gia dinh', 'Vu tru hoc', 'FME', 'Kinh te', 'Luat',
#        'Tuong lai hoc', 'Tinh truong hoc'], dtype=object)

# %%
import pandas as pd             #Xoa 1 cot
url = 'file_ten.csv'
dataframe = pd.read_csv(url)
dataframe.drop('Diem',axis=1).head(5)
# Out:
#        MSSV      Ho Va Ten  Nam nhap hoc                 Khoa
# 0  20146526       Le Van A            20                  CKM
# 1  20146565   Nguyen Van B            20                  CKM
# 2  19146262  Dinh La Thang            19  Cong nghe thuc pham
# 3  21996543      Cao Vi Mo            21          Hoa loc dau
# 4  22876543   Sieu Cao Thu            22         Cong Nghe In

# %%
import pandas as pd
url = 'file_ten.csv'
dataframe = pd.read_csv(url)
dataframe.groupby(dataframe['Diem']>= 8).count()
# Out:
#        MSSV  Ho Va Ten  Nam nhap hoc  Khoa  Diem
# Diem
# False     1          1             1     1     1
# True     14         14            14    14    14

# %%
import pandas as pd
url = 'http://winterolympicsmedals.com/medals.csv'
dataframe = pd.read_csv(url)
dataframe[dataframe['City']=='Chamonix'].head(100)
# Out:
#     Year      City       Sport       Discipline  NOC                 Event  \
# 0   1924  Chamonix     Skating   Figure skating  AUT            individual
# 1   1924  Chamonix     Skating   Figure skating  AUT            individual
# 2   1924  Chamonix     Skating   Figure skating  AUT                 pairs
# 3   1924  Chamonix   Bobsleigh        Bobsleigh  BEL              four-man
# 4   1924  Chamonix  Ice Hockey       Ice Hockey  CAN            ice hockey
# 5   1924  Chamonix    Biathlon         Biathlon  FIN       military patrol
# 6   1924  Chamonix     Skating   Figure skating  FIN                 pairs
# 7   1924  Chamonix     Skating    Speed skating  FIN                10000m
# 8   1924  Chamonix     Skating    Speed skating  FIN                10000m
# 9   1924  Chamonix     Skating    Speed skating  FIN                 1500m
# 10  1924  Chamonix     Skating    Speed skating  FIN                 5000m
# ...

# %%
import pandas as pd
url = 'http://winterolympicsmedals.com/medals.csv'
dataframe = pd.read_csv(url)
dataframe[(dataframe['City']=='Chamonix') & (dataframe['Year']==1924)].head(100)
# Out:
#     Year      City       Sport       Discipline  NOC                 Event  \
# 0   1924  Chamonix     Skating   Figure skating  AUT            individual
# 1   1924  Chamonix     Skating   Figure skating  AUT            individual
# 2   1924  Chamonix     Skating   Figure skating  AUT                 pairs
# 3   1924  Chamonix   Bobsleigh        Bobsleigh  BEL              four-man
# 4   1924  Chamonix  Ice Hockey       Ice Hockey  CAN            ice hockey
# 5   1924  Chamonix    Biathlon         Biathlon  FIN       military patrol
# 6   1924  Chamonix     Skating   Figure skating  FIN                 pairs
# 7   1924  Chamonix     Skating    Speed skating  FIN                10000m
# 8   1924  Chamonix     Skating    Speed skating  FIN                10000m
# 9   1924  Chamonix     Skating    Speed skating  FIN                 1500m
# 10  1924  Chamonix     Skating    Speed skating  FIN                 5000m
# ...

# %%
import pandas as pd
url = 'http://winterolympicsmedals.com/medals.csv'
dataframe = pd.read_csv(url)
dataframe[(dataframe['City']=='Chamonix') & (dataframe['Year']==1924) & (dataframe['Medal']=='Gold')].head(100)
# Out:
#     Year      City       Sport       Discipline  NOC                 Event  \
# 1   1924  Chamonix     Skating   Figure skating  AUT            individual
# 2   1924  Chamonix     Skating   Figure skating  AUT                 pairs
# 4   1924  Chamonix  Ice Hockey       Ice Hockey  CAN            ice hockey
# 7   1924  Chamonix     Skating    Speed skating  FIN                10000m
# 9   1924  Chamonix     Skating    Speed skating  FIN                 1500m
# 10  1924  Chamonix     Skating    Speed skating  FIN                 5000m
# 14  1924  Chamonix     Skating    Speed skating  FIN   combined (4 events)
# 20  1924  Chamonix     Curling          Curling  GBR               curling
# 30  1924  Chamonix      Skiing  Cross Country S  NOR                  18km
# 33  1924  Chamonix      Skiing  Cross Country S  NOR                  50km
# 36  1924  Chamonix      Skiing  Nordic Combined  NOR            individual
# ...

# %%
import pandas as pd
url = 'http://winterolympicsmedals.com/medals.csv'
dataframe = pd.read_csv(url)

dataframe[(dataframe['City']=='Chamonix') & (dataframe['Year']==1924) & (dataframe['Medal']=='Gold') & (dataframe['Discipline']=='Figure skating')].head(100)
# Out:
#     Year      City    Sport      Discipline  NOC       Event Event gender  \
# 1   1924  Chamonix  Skating  Figure skating  AUT  individual            W
# 2   1924  Chamonix  Skating  Figure skating  AUT       pairs            X
# 44  1924  Chamonix  Skating  Figure skating  SWE  individual            M
#
#    Medal
# 1   Gold
# 2   Gold
# 44  Gold

# %% [markdown]
# # Mục mới
